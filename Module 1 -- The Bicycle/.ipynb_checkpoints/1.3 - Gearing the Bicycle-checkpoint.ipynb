# %% [markdown]
# # Module 1.3: Gearing and Programming the Bicycle:

# %% [markdown]
# ## Gearing the Bicycle:

# %% [markdown]
# ### Step 1: Reconfiguring the Back Wheel
# Modify the bicycle to match the design shown below:
#
# <div>
#  <img src="attachment:bicycle1-2.JPG" width="300" style="margin:0px"/>
# </div>

# %% [markdown]
# ### Step 2: Adding Gears and Wheels
# Then, add gears and wheels as shown below:
#
# <div>
#  <img src="attachment:bicycle2-2.JPG" width="300" style="margin:0px"/>
#
# </div>

# %% [markdown]
# ## Testing the Bicycle:
#
# #### Connecting to Spike:
# Make sure the motor is plugged into port D. Then, run the code to search for serial ports and select your hub.

# %%
# %run ./module_1_helper_functions.ipynb
updatedPortList = search_for_ports()
dropdown = widgets.Select(
            options=updatedPortList,
            description='Select Port:',
            disabled=False)
output2 = widgets.Output()
display(dropdown, output2)
dropdown.observe(on_value_change2, names='value')
# Out:
# Select(description='Select Port:', options=('/dev/cu.Bluetooth-Incoming-Port', '/dev/cu.LEGOHub30E283048E8E', …
# Output()

# %% [markdown]
# #### Controlling the motor:
#
# Run the cell below and use the controls to move your bicycle.

# %%
controlBicycle()
# Out:
# Button(icon='arrow-up', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', widt…
# Output()
# Button(icon='stop', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', width='4…
# Output()
# Button(icon='arrow-down', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', wi…
# Output()

# %% [markdown]
# ## Investigating and Selecting a Gear Ratio:
#
# How do the sizes of the gears that we choose affect the speed that the wheels turn at? How do they affect the power with which the wheels turn?
#
# To answer these questions, test the bicycle with the following gear configurations:
#
#
# <div>
#  <img src="attachment:IMG_3490.JPG" width="600" style="margin:0px"/>
#
# </div>
#
# Which configuration would allow the bicycle to move fastest on a flat surface? Which configuration would allow the bicycle to drive up the steepest incline?
#
# When selecting gear ratios, there are two main factors that we need to consider:
#
# * **Speed** -- how fast the output gear turns
# * **Torque** -- the force with which the output gear turns
#
# Run the cell below to check your understanding about speed and torque.

# %%
# %run ./module_1_helper_functions.ipynb
speed_and_torque_questions()
# Out:
# Dropdown(layout=Layout(width='initial'), options=('Which set of gears will cause the wheel to turn with the mo…
# Output()
# Dropdown(layout=Layout(width='initial'), options=('Which set of gears will cause the wheel to turn with the mo…
# Output()

# %% [markdown]
# Now, select a gear ratio and update your bicycle.

# %% [markdown]
# ## Programming the Bicycle:
#
# Using the following functions, code your robot to drive forward quickly, stop, and reverse slowly until it reaches its starting point:
# * delay(*number of seconds*)
# * stop()
# * move(*speed from -100 to 100*)
#
# Run the cell below and code in the space that appears.

# %%
# %run ./module_1_helper_functions.ipynb
code_bicycle()
# Out:
# Textarea(value='')
# Button(button_style='success', description='Run Code', icon='play', style=ButtonStyle(), tooltip='Click me')
# Output()

# %% [markdown]
# Once you complete this, you are ready to move on to the next section!
