# %% [markdown]
# # Module 1.2: Constructing and Controlling the Bicycle:

# %% [markdown]
# ## Constructing the Bicycle:
#
# #### You will need:
# * 2x Black 15m Beam
# * 3x Wheel
# * 1x Large Hub
# * 1x Black Biscut 1x3x3
# * 2x Gray Angle Element, 0 Degrees
# * 1x Black Cross Axle 4m
# * 1x Black Cross Axle 8m
# * 1x Medium Motor
# * 10x Connector Peg
#
# #### Assembly:
#
# ![IMG_3257.JPG](attachment:IMG_3257.JPG)

# %% [markdown]
# ## Controlling the Bicycle:
#
# #### Connecting to Spike:
# Make sure the motor is plugged into port D. Then, run the code below to search for serial ports and select your hub.

# %%
# %run ./module_1_helper_functions.ipynb
updatedPortList = search_for_ports()
dropdown = widgets.Select(
            options=updatedPortList,
            description='Select Port:',
            disabled=False)
output2 = widgets.Output()
display(dropdown, output2)
dropdown.observe(on_value_change2, names='value')
# Out:
# Select(description='Select Port:', options=('/dev/cu.Bluetooth-Incoming-Port', '/dev/cu.LEGOHub30E283048E8E', …
# Output()

# %% [markdown]
# #### Controlling the motor:
#
# Run the cell below and use the controls to move your bicycle.

# %%
controlBicycle()
# Out:
# Button(icon='arrow-up', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', widt…
# Output()
# Button(icon='stop', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', width='4…
# Output()
# Button(icon='arrow-down', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', wi…
# Output()

# %% [markdown]
# Once you are done, you may move on to the next section!
