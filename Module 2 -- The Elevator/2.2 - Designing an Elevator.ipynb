# %% [markdown]
# <div>
#  <img src="attachment:Screen%20Shot%202022-10-28%20at%201.38.28%20PM.png" width="600" style="margin:0px"/>
# </div>

# %% [markdown]
# # Module 2.2: Designing an Elevator!

# %% [markdown]
# ### Constructing the Elevator Shaft:
#
# Assemble the structure depicted below. (You may make small modifications, but preserve the distance between the magenta frames).
#
# <div>
#  <img src="attachment:Screen%20Shot%202022-10-28%20at%201.38.28%20PM.png" width="450"/>
# </div>

# %% [markdown]
# ### Designing the Elevator:
#
# Now, you will use your knowledge about linear motion to build a LEGO elevator that will transport a minifigure between the two magenta frames. Some specifics:
#
# * Your elevator must utilize exactly one motor
# * The minifigure must start at the height of the lower edge of the bottom magenta frame and rise to the height of the lower edge of the top magenta frame.
# * The minifigure must be standing on a platform throughout its ride.
# * You are allowed to raise the height of the lower frame, but you may not decrease the distance between the two magenta frames
# * You may use any of the parts in your SPIKE kit, as well as any common household items (such as string) if you wish.
#
# In designing the mechanism that will transport your minifigure between levels, you may either modify one of the mechanisms that you explored in Module 2.1 or create your own entirely. Regardless, you will likely need to dissasemble the mechanisms you constructed in Module 2.1.

# %% [markdown]
# ### Controlling the Elevator:
# Connect the motor to port D and control using the buttons below.

# %%
# %run ./module_2_helper_functions.ipynb
updatedPortList = search_for_ports()
dropdown = widgets.Select(
            options=updatedPortList,
            description='Select Port:',
            disabled=False)
output2 = widgets.Output()
display(dropdown, output2)
dropdown.observe(on_value_change, names='value')
controlElevator()
# Out:
# Select(description='Select Port:', options=('/dev/cu.Bluetooth-Incoming-Port', '/dev/cu.LEGOHub30E283048E8E', …
# Output()
# Button(icon='arrow-up', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', widt…
# Output()
# Button(icon='stop', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', width='4…
# Output()
# Button(icon='arrow-down', layout=Layout(height='40px', margin='0px 0px 0px 0px', padding='0px 0px 0px 0px', wi…
# Output()

# %% [markdown]
# When you are ready to program your elevator, you may move on to the next section.
